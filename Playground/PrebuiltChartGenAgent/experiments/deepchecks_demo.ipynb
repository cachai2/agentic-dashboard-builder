# %%
from pathlib import Path
import json
import pandas as pd

plan_path = Path('..') / 'tests' / 'data' / 'sample_plan.json'
with plan_path.open('r', encoding='utf-8') as handle:
    plan = json.load(handle)
section = plan['sections'][1]
df = pd.DataFrame(section['dataset']['records'])
display(df)
# TODO: import deepchecks.tabular.suites as suites and run suites.data_integrity()
