# %%
from pathlib import Path
import json
import pandas as pd

plan_path = Path('..') / 'tests' / 'data' / 'sample_plan.json'
with plan_path.open('r', encoding='utf-8') as handle:
    plan = json.load(handle)
section = plan['sections'][0]
df = pd.DataFrame(section['dataset']['rows'], columns=section['dataset']['columns'])
display(df.head())
# TODO: from autoviz.AutoViz_Class import AutoViz_Class and render the artifact here
